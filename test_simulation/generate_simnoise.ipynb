# %%
from test_nuradio_single import NuRadioRecoReader
from NuRadioReco.detector import detector
from NuRadioReco.utilities import units
from NuRadioReco.detector.antennapattern import preprocess_LOFAR_txt
import datetime
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ERROR - 2026-08-03 16:20:01,202 - NuRadioReco.channelGalacticNoiseAdder - pylfmap import failed. This might be because you do not have a working installation of cfitsio. See https://github.com/F-Tomas/pylfmap/issues/2 for potential tips

# %%
path_to_response = "/home/rkitahara/Research/Cov/test_simulation/antenna_response_lofar"

path_to_coreas_sim_file = "/home/rkitahara/Research/Cov/test_simulation/93970574/0/proton/SIM000018.hdf5"

det = detector.Detector(
    "LOFAR/LOFAR.json", source="json", antenna_by_depth=False
)
det.update(datetime.datetime(2013, 1, 1, 0, 0, 0))

selected_station_channel_ids = {}
for staid in [1, 2, 3, 4, 5, 6, 7]:
    selected_station_channel_ids[staid] = det.get_channel_ids(staid)
# for staid in [1, 2]:
#     selected_station_channel_ids[staid] = det.get_channel_ids(staid)

core_xy = np.array([0, 0]) * units.m

preprocess_LOFAR_txt(path_to_response, orientation="Y")
preprocess_LOFAR_txt(path_to_response, orientation="X")

# %%
reader = NuRadioRecoReader(det,filt_settings={"passband": [30 * units.MHz, 80 * units.MHz], "filter_type": "butter", "order": 10})

evt = reader.read_data_event_with_noise(path_to_coreas_sim_file, selected_station_channel_ids=selected_station_channel_ids, core=core_xy, Tnoise=300 * units.K)
# Out:
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# WARNING - 2026-08-03 16:20:22,087 - NuRadioReco.detector - Cable delay not set for channel 1000000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,087 - NuRadioReco.detector - Cable delay not set for channel 1000001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,088 - NuRadioReco.detector - Cable delay not set for channel 1000002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,088 - NuRadioReco.detector - Cable delay not set for channel 1000003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,089 - NuRadioReco.detector - Cable delay not set for channel 1000004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,089 - NuRadioReco.detector - Cable delay not set for channel 1000005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,089 - NuRadioReco.detector - Cable delay not set for channel 1000006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,090 - NuRadioReco.detector - Cable delay not set for channel 1000007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,090 - NuRadioReco.detector - Cable delay not set for channel 1001008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,091 - NuRadioReco.detector - Cable delay not set for channel 1001009 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,091 - NuRadioReco.detector - Cable delay not set for channel 1001010 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,091 - NuRadioReco.detector - Cable delay not set for channel 1001011 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,092 - NuRadioReco.detector - Cable delay not set for channel 1001012 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,092 - NuRadioReco.detector - Cable delay not set for channel 1001013 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,092 - NuRadioReco.detector - Cable delay not set for channel 1001014 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,093 - NuRadioReco.detector - Cable delay not set for channel 1001015 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,093 - NuRadioReco.detector - Cable delay not set for channel 1002016 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,094 - NuRadioReco.detector - Cable delay not set for channel 1002017 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,094 - NuRadioReco.detector - Cable delay not set for channel 1002018 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,094 - NuRadioReco.detector - Cable delay not set for channel 1002019 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,095 - NuRadioReco.detector - Cable delay not set for channel 1002020 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,095 - NuRadioReco.detector - Cable delay not set for channel 1002021 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,096 - NuRadioReco.detector - Cable delay not set for channel 1002022 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,096 - NuRadioReco.detector - Cable delay not set for channel 1002023 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,096 - NuRadioReco.detector - Cable delay not set for channel 1003024 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,097 - NuRadioReco.detector - Cable delay not set for channel 1003025 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,098 - NuRadioReco.detector - Cable delay not set for channel 1003026 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,099 - NuRadioReco.detector - Cable delay not set for channel 1003027 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,099 - NuRadioReco.detector - Cable delay not set for channel 1003028 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,100 - NuRadioReco.detector - Cable delay not set for channel 1003029 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,100 - NuRadioReco.detector - Cable delay not set for channel 1003030 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,101 - NuRadioReco.detector - Cable delay not set for channel 1003031 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,101 - NuRadioReco.detector - Cable delay not set for channel 1004032 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,101 - NuRadioReco.detector - Cable delay not set for channel 1004033 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,102 - NuRadioReco.detector - Cable delay not set for channel 1004034 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,102 - NuRadioReco.detector - Cable delay not set for channel 1004035 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,103 - NuRadioReco.detector - Cable delay not set for channel 1004036 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,103 - NuRadioReco.detector - Cable delay not set for channel 1004037 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,103 - NuRadioReco.detector - Cable delay not set for channel 1004038 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,104 - NuRadioReco.detector - Cable delay not set for channel 1004039 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,104 - NuRadioReco.detector - Cable delay not set for channel 1005040 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,105 - NuRadioReco.detector - Cable delay not set for channel 1005041 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,105 - NuRadioReco.detector - Cable delay not set for channel 1005042 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,106 - NuRadioReco.detector - Cable delay not set for channel 1005043 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,106 - NuRadioReco.detector - Cable delay not set for channel 1005044 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,106 - NuRadioReco.detector - Cable delay not set for channel 1005045 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,107 - NuRadioReco.detector - Cable delay not set for channel 1005046 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,107 - NuRadioReco.detector - Cable delay not set for channel 1005047 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,108 - NuRadioReco.detector - Cable delay not set for channel 1006048 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,109 - NuRadioReco.detector - Cable delay not set for channel 1006049 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,110 - NuRadioReco.detector - Cable delay not set for channel 1006050 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,110 - NuRadioReco.detector - Cable delay not set for channel 1006051 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,110 - NuRadioReco.detector - Cable delay not set for channel 1006052 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,111 - NuRadioReco.detector - Cable delay not set for channel 1006053 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,111 - NuRadioReco.detector - Cable delay not set for channel 1006054 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,112 - NuRadioReco.detector - Cable delay not set for channel 1006055 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,112 - NuRadioReco.detector - Cable delay not set for channel 1007056 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,113 - NuRadioReco.detector - Cable delay not set for channel 1007057 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,113 - NuRadioReco.detector - Cable delay not set for channel 1007058 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,113 - NuRadioReco.detector - Cable delay not set for channel 1007059 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,114 - NuRadioReco.detector - Cable delay not set for channel 1007060 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,114 - NuRadioReco.detector - Cable delay not set for channel 1007061 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,114 - NuRadioReco.detector - Cable delay not set for channel 1007062 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,115 - NuRadioReco.detector - Cable delay not set for channel 1007063 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,116 - NuRadioReco.detector - Cable delay not set for channel 1008064 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,116 - NuRadioReco.detector - Cable delay not set for channel 1008065 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,117 - NuRadioReco.detector - Cable delay not set for channel 1008066 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,117 - NuRadioReco.detector - Cable delay not set for channel 1008067 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,117 - NuRadioReco.detector - Cable delay not set for channel 1008068 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,118 - NuRadioReco.detector - Cable delay not set for channel 1008069 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,118 - NuRadioReco.detector - Cable delay not set for channel 1008070 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,118 - NuRadioReco.detector - Cable delay not set for channel 1008071 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,119 - NuRadioReco.detector - Cable delay not set for channel 1009072 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,119 - NuRadioReco.detector - Cable delay not set for channel 1009073 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,120 - NuRadioReco.detector - Cable delay not set for channel 1009074 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,120 - NuRadioReco.detector - Cable delay not set for channel 1009075 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,120 - NuRadioReco.detector - Cable delay not set for channel 1009076 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,121 - NuRadioReco.detector - Cable delay not set for channel 1009077 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,121 - NuRadioReco.detector - Cable delay not set for channel 1009078 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,121 - NuRadioReco.detector - Cable delay not set for channel 1009079 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,122 - NuRadioReco.detector - Cable delay not set for channel 1010080 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,122 - NuRadioReco.detector - Cable delay not set for channel 1010081 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,123 - NuRadioReco.detector - Cable delay not set for channel 1010082 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,123 - NuRadioReco.detector - Cable delay not set for channel 1010083 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,124 - NuRadioReco.detector - Cable delay not set for channel 1010084 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,124 - NuRadioReco.detector - Cable delay not set for channel 1010085 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,125 - NuRadioReco.detector - Cable delay not set for channel 1010086 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,125 - NuRadioReco.detector - Cable delay not set for channel 1010087 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,126 - NuRadioReco.detector - Cable delay not set for channel 1011088 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,126 - NuRadioReco.detector - Cable delay not set for channel 1011089 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,126 - NuRadioReco.detector - Cable delay not set for channel 1011090 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,127 - NuRadioReco.detector - Cable delay not set for channel 1011091 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,127 - NuRadioReco.detector - Cable delay not set for channel 1011092 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,128 - NuRadioReco.detector - Cable delay not set for channel 1011093 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,128 - NuRadioReco.detector - Cable delay not set for channel 1011094 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,128 - NuRadioReco.detector - Cable delay not set for channel 1011095 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,129 - NuRadioReco.detector - Cable delay not set for channel 1900000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,129 - NuRadioReco.detector - Cable delay not set for channel 1900001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,129 - NuRadioReco.detector - Cable delay not set for channel 1900002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,130 - NuRadioReco.detector - Cable delay not set for channel 1900003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,130 - NuRadioReco.detector - Cable delay not set for channel 1900004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,130 - NuRadioReco.detector - Cable delay not set for channel 1900005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,131 - NuRadioReco.detector - Cable delay not set for channel 1900006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,131 - NuRadioReco.detector - Cable delay not set for channel 1900007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,131 - NuRadioReco.detector - Cable delay not set for channel 1901008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,133 - NuRadioReco.detector - Cable delay not set for channel 1901009 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,133 - NuRadioReco.detector - Cable delay not set for channel 1901010 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,134 - NuRadioReco.detector - Cable delay not set for channel 1901011 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,134 - NuRadioReco.detector - Cable delay not set for channel 1901012 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,135 - NuRadioReco.detector - Cable delay not set for channel 1901013 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,135 - NuRadioReco.detector - Cable delay not set for channel 1901014 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,135 - NuRadioReco.detector - Cable delay not set for channel 1901015 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,136 - NuRadioReco.detector - Cable delay not set for channel 1902016 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,136 - NuRadioReco.detector - Cable delay not set for channel 1902017 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,136 - NuRadioReco.detector - Cable delay not set for channel 1902018 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,137 - NuRadioReco.detector - Cable delay not set for channel 1902019 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,138 - NuRadioReco.detector - Cable delay not set for channel 1902020 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,138 - NuRadioReco.detector - Cable delay not set for channel 1902021 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,138 - NuRadioReco.detector - Cable delay not set for channel 1902022 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,139 - NuRadioReco.detector - Cable delay not set for channel 1902023 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,139 - NuRadioReco.detector - Cable delay not set for channel 1903024 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,139 - NuRadioReco.detector - Cable delay not set for channel 1903025 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,140 - NuRadioReco.detector - Cable delay not set for channel 1903026 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,140 - NuRadioReco.detector - Cable delay not set for channel 1903027 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,141 - NuRadioReco.detector - Cable delay not set for channel 1903028 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,141 - NuRadioReco.detector - Cable delay not set for channel 1903029 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,141 - NuRadioReco.detector - Cable delay not set for channel 1903030 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,142 - NuRadioReco.detector - Cable delay not set for channel 1903031 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,142 - NuRadioReco.detector - Cable delay not set for channel 1904032 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,142 - NuRadioReco.detector - Cable delay not set for channel 1904033 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,143 - NuRadioReco.detector - Cable delay not set for channel 1904034 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,143 - NuRadioReco.detector - Cable delay not set for channel 1904035 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,145 - NuRadioReco.detector - Cable delay not set for channel 1904036 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,145 - NuRadioReco.detector - Cable delay not set for channel 1904037 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,146 - NuRadioReco.detector - Cable delay not set for channel 1904038 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,146 - NuRadioReco.detector - Cable delay not set for channel 1904039 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,146 - NuRadioReco.detector - Cable delay not set for channel 1905040 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,147 - NuRadioReco.detector - Cable delay not set for channel 1905041 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,147 - NuRadioReco.detector - Cable delay not set for channel 1905042 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,148 - NuRadioReco.detector - Cable delay not set for channel 1905043 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,148 - NuRadioReco.detector - Cable delay not set for channel 1905044 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,149 - NuRadioReco.detector - Cable delay not set for channel 1905045 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,149 - NuRadioReco.detector - Cable delay not set for channel 1905046 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,149 - NuRadioReco.detector - Cable delay not set for channel 1905047 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,150 - NuRadioReco.detector - Cable delay not set for channel 1906048 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,150 - NuRadioReco.detector - Cable delay not set for channel 1906049 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,151 - NuRadioReco.detector - Cable delay not set for channel 1906050 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,151 - NuRadioReco.detector - Cable delay not set for channel 1906051 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,152 - NuRadioReco.detector - Cable delay not set for channel 1906052 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,152 - NuRadioReco.detector - Cable delay not set for channel 1906053 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,152 - NuRadioReco.detector - Cable delay not set for channel 1906054 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,153 - NuRadioReco.detector - Cable delay not set for channel 1906055 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,153 - NuRadioReco.detector - Cable delay not set for channel 1907056 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,154 - NuRadioReco.detector - Cable delay not set for channel 1907057 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,154 - NuRadioReco.detector - Cable delay not set for channel 1907058 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,155 - NuRadioReco.detector - Cable delay not set for channel 1907059 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,155 - NuRadioReco.detector - Cable delay not set for channel 1907060 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,155 - NuRadioReco.detector - Cable delay not set for channel 1907061 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,156 - NuRadioReco.detector - Cable delay not set for channel 1907062 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,156 - NuRadioReco.detector - Cable delay not set for channel 1907063 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,157 - NuRadioReco.detector - Cable delay not set for channel 1908064 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,157 - NuRadioReco.detector - Cable delay not set for channel 1908065 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,157 - NuRadioReco.detector - Cable delay not set for channel 1908066 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,157 - NuRadioReco.detector - Cable delay not set for channel 1908067 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,158 - NuRadioReco.detector - Cable delay not set for channel 1908068 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,158 - NuRadioReco.detector - Cable delay not set for channel 1908069 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,158 - NuRadioReco.detector - Cable delay not set for channel 1908070 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,159 - NuRadioReco.detector - Cable delay not set for channel 1908071 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,159 - NuRadioReco.detector - Cable delay not set for channel 1909072 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,159 - NuRadioReco.detector - Cable delay not set for channel 1909073 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,160 - NuRadioReco.detector - Cable delay not set for channel 1909074 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,160 - NuRadioReco.detector - Cable delay not set for channel 1909075 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,160 - NuRadioReco.detector - Cable delay not set for channel 1909076 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,161 - NuRadioReco.detector - Cable delay not set for channel 1909077 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,161 - NuRadioReco.detector - Cable delay not set for channel 1909078 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,161 - NuRadioReco.detector - Cable delay not set for channel 1909079 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,162 - NuRadioReco.detector - Cable delay not set for channel 1910080 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,162 - NuRadioReco.detector - Cable delay not set for channel 1910081 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,162 - NuRadioReco.detector - Cable delay not set for channel 1910082 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,163 - NuRadioReco.detector - Cable delay not set for channel 1910083 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,163 - NuRadioReco.detector - Cable delay not set for channel 1910084 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,163 - NuRadioReco.detector - Cable delay not set for channel 1910085 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,164 - NuRadioReco.detector - Cable delay not set for channel 1910086 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,164 - NuRadioReco.detector - Cable delay not set for channel 1910087 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,165 - NuRadioReco.detector - Cable delay not set for channel 1911088 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,165 - NuRadioReco.detector - Cable delay not set for channel 1911089 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,165 - NuRadioReco.detector - Cable delay not set for channel 1911090 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,166 - NuRadioReco.detector - Cable delay not set for channel 1911091 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,166 - NuRadioReco.detector - Cable delay not set for channel 1911092 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,167 - NuRadioReco.detector - Cable delay not set for channel 1911093 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,168 - NuRadioReco.detector - Cable delay not set for channel 1911094 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,168 - NuRadioReco.detector - Cable delay not set for channel 1911095 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,169 - NuRadioReco.detector - Cable delay not set for channel 1000000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,178 - NuRadioReco.antennapattern - no hash sum of LOFAR_LBA_Y.pkl available, skipping up-to-date check
# STATUS - 2026-08-03 16:20:22,180 - NuRadioReco.antennapattern - Performing consistency check on antenna response ...
# STATUS - 2026-08-03 16:20:22,215 - NuRadioReco.antennapattern - Loading antenna file LOFAR_LBA_Y took 0.0 seconds
# WARNING - 2026-08-03 16:20:22,219 - NuRadioReco.detector - Cable delay not set for channel 1000001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,226 - NuRadioReco.antennapattern - no hash sum of LOFAR_LBA_X.pkl available, skipping up-to-date check
# STATUS - 2026-08-03 16:20:22,229 - NuRadioReco.antennapattern - Performing consistency check on antenna response ...
# STATUS - 2026-08-03 16:20:22,259 - NuRadioReco.antennapattern - Loading antenna file LOFAR_LBA_X took 0.0 seconds
# WARNING - 2026-08-03 16:20:22,262 - NuRadioReco.detector - Cable delay not set for channel 1000002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,267 - NuRadioReco.detector - Cable delay not set for channel 1000003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,270 - NuRadioReco.detector - Cable delay not set for channel 1000004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,273 - NuRadioReco.detector - Cable delay not set for channel 1000005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,277 - NuRadioReco.detector - Cable delay not set for channel 1000006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,280 - NuRadioReco.detector - Cable delay not set for channel 1000007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,284 - NuRadioReco.detector - Cable delay not set for channel 1001008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,289 - NuRadioReco.detector - Cable delay not set for channel 1001009 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,293 - NuRadioReco.detector - Cable delay not set for channel 1001010 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,297 - NuRadioReco.detector - Cable delay not set for channel 1001011 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,301 - NuRadioReco.detector - Cable delay not set for channel 1001012 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,305 - NuRadioReco.detector - Cable delay not set for channel 1001013 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,309 - NuRadioReco.detector - Cable delay not set for channel 1001014 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,313 - NuRadioReco.detector - Cable delay not set for channel 1001015 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,318 - NuRadioReco.detector - Cable delay not set for channel 1002016 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,321 - NuRadioReco.detector - Cable delay not set for channel 1002017 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,325 - NuRadioReco.detector - Cable delay not set for channel 1002018 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,328 - NuRadioReco.detector - Cable delay not set for channel 1002019 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,331 - NuRadioReco.detector - Cable delay not set for channel 1002020 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,335 - NuRadioReco.detector - Cable delay not set for channel 1002021 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,339 - NuRadioReco.detector - Cable delay not set for channel 1002022 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,342 - NuRadioReco.detector - Cable delay not set for channel 1002023 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,345 - NuRadioReco.detector - Cable delay not set for channel 1003024 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,349 - NuRadioReco.detector - Cable delay not set for channel 1003025 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,352 - NuRadioReco.detector - Cable delay not set for channel 1003026 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,357 - NuRadioReco.detector - Cable delay not set for channel 1003027 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,360 - NuRadioReco.detector - Cable delay not set for channel 1003028 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,363 - NuRadioReco.detector - Cable delay not set for channel 1003029 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,367 - NuRadioReco.detector - Cable delay not set for channel 1003030 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,371 - NuRadioReco.detector - Cable delay not set for channel 1003031 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,374 - NuRadioReco.detector - Cable delay not set for channel 1004032 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,377 - NuRadioReco.detector - Cable delay not set for channel 1004033 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,380 - NuRadioReco.detector - Cable delay not set for channel 1004034 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,384 - NuRadioReco.detector - Cable delay not set for channel 1004035 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,388 - NuRadioReco.detector - Cable delay not set for channel 1004036 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,391 - NuRadioReco.detector - Cable delay not set for channel 1004037 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,394 - NuRadioReco.detector - Cable delay not set for channel 1004038 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,398 - NuRadioReco.detector - Cable delay not set for channel 1004039 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,402 - NuRadioReco.detector - Cable delay not set for channel 1005040 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,405 - NuRadioReco.detector - Cable delay not set for channel 1005041 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,408 - NuRadioReco.detector - Cable delay not set for channel 1005042 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,411 - NuRadioReco.detector - Cable delay not set for channel 1005043 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,415 - NuRadioReco.detector - Cable delay not set for channel 1005044 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,419 - NuRadioReco.detector - Cable delay not set for channel 1005045 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,423 - NuRadioReco.detector - Cable delay not set for channel 1005046 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,427 - NuRadioReco.detector - Cable delay not set for channel 1005047 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,430 - NuRadioReco.detector - Cable delay not set for channel 1006048 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,434 - NuRadioReco.detector - Cable delay not set for channel 1006049 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,438 - NuRadioReco.detector - Cable delay not set for channel 1006050 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,441 - NuRadioReco.detector - Cable delay not set for channel 1006051 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,445 - NuRadioReco.detector - Cable delay not set for channel 1006052 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,448 - NuRadioReco.detector - Cable delay not set for channel 1006053 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,452 - NuRadioReco.detector - Cable delay not set for channel 1006054 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,455 - NuRadioReco.detector - Cable delay not set for channel 1006055 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,458 - NuRadioReco.detector - Cable delay not set for channel 1007056 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,462 - NuRadioReco.detector - Cable delay not set for channel 1007057 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,466 - NuRadioReco.detector - Cable delay not set for channel 1007058 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,469 - NuRadioReco.detector - Cable delay not set for channel 1007059 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,472 - NuRadioReco.detector - Cable delay not set for channel 1007060 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,475 - NuRadioReco.detector - Cable delay not set for channel 1007061 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,479 - NuRadioReco.detector - Cable delay not set for channel 1007062 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,482 - NuRadioReco.detector - Cable delay not set for channel 1007063 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,486 - NuRadioReco.detector - Cable delay not set for channel 1008064 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,490 - NuRadioReco.detector - Cable delay not set for channel 1008065 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,493 - NuRadioReco.detector - Cable delay not set for channel 1008066 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,496 - NuRadioReco.detector - Cable delay not set for channel 1008067 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,500 - NuRadioReco.detector - Cable delay not set for channel 1008068 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,503 - NuRadioReco.detector - Cable delay not set for channel 1008069 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,506 - NuRadioReco.detector - Cable delay not set for channel 1008070 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,510 - NuRadioReco.detector - Cable delay not set for channel 1008071 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,514 - NuRadioReco.detector - Cable delay not set for channel 1009072 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,518 - NuRadioReco.detector - Cable delay not set for channel 1009073 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,522 - NuRadioReco.detector - Cable delay not set for channel 1009074 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,525 - NuRadioReco.detector - Cable delay not set for channel 1009075 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,528 - NuRadioReco.detector - Cable delay not set for channel 1009076 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,531 - NuRadioReco.detector - Cable delay not set for channel 1009077 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,536 - NuRadioReco.detector - Cable delay not set for channel 1009078 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,540 - NuRadioReco.detector - Cable delay not set for channel 1009079 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,543 - NuRadioReco.detector - Cable delay not set for channel 1010080 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,546 - NuRadioReco.detector - Cable delay not set for channel 1010081 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,550 - NuRadioReco.detector - Cable delay not set for channel 1010082 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,554 - NuRadioReco.detector - Cable delay not set for channel 1010083 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,557 - NuRadioReco.detector - Cable delay not set for channel 1010084 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,560 - NuRadioReco.detector - Cable delay not set for channel 1010085 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,563 - NuRadioReco.detector - Cable delay not set for channel 1010086 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,566 - NuRadioReco.detector - Cable delay not set for channel 1010087 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,570 - NuRadioReco.detector - Cable delay not set for channel 1011088 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,573 - NuRadioReco.detector - Cable delay not set for channel 1011089 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,576 - NuRadioReco.detector - Cable delay not set for channel 1011090 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,579 - NuRadioReco.detector - Cable delay not set for channel 1011091 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,582 - NuRadioReco.detector - Cable delay not set for channel 1011092 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,586 - NuRadioReco.detector - Cable delay not set for channel 1011093 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,590 - NuRadioReco.detector - Cable delay not set for channel 1011094 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,592 - NuRadioReco.detector - Cable delay not set for channel 1011095 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,596 - NuRadioReco.detector - Cable delay not set for channel 1900000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,599 - NuRadioReco.detector - Cable delay not set for channel 1900001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,603 - NuRadioReco.detector - Cable delay not set for channel 1900002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,606 - NuRadioReco.detector - Cable delay not set for channel 1900003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,609 - NuRadioReco.detector - Cable delay not set for channel 1900004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,613 - NuRadioReco.detector - Cable delay not set for channel 1900005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:22,616 - NuRadioReco.detector - Cable delay not set for channel 1900006 in station 1, assuming cable delay is zero
# ...
# WARNING - 2026-08-03 16:20:39,453 - NuRadioReco.detector - Cable delay not set for channel 7010080 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,456 - NuRadioReco.detector - Cable delay not set for channel 7010081 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,459 - NuRadioReco.detector - Cable delay not set for channel 7010082 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,463 - NuRadioReco.detector - Cable delay not set for channel 7010083 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,466 - NuRadioReco.detector - Cable delay not set for channel 7010084 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,469 - NuRadioReco.detector - Cable delay not set for channel 7010085 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,473 - NuRadioReco.detector - Cable delay not set for channel 7010086 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,476 - NuRadioReco.detector - Cable delay not set for channel 7010087 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,493 - NuRadioReco.detector - Cable delay not set for channel 7011088 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,501 - NuRadioReco.detector - Cable delay not set for channel 7011089 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,506 - NuRadioReco.detector - Cable delay not set for channel 7011090 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,510 - NuRadioReco.detector - Cable delay not set for channel 7011091 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,514 - NuRadioReco.detector - Cable delay not set for channel 7011092 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,517 - NuRadioReco.detector - Cable delay not set for channel 7011093 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,520 - NuRadioReco.detector - Cable delay not set for channel 7011094 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,524 - NuRadioReco.detector - Cable delay not set for channel 7011095 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,527 - NuRadioReco.detector - Cable delay not set for channel 7900000 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,530 - NuRadioReco.detector - Cable delay not set for channel 7900001 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,533 - NuRadioReco.detector - Cable delay not set for channel 7900002 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,536 - NuRadioReco.detector - Cable delay not set for channel 7900003 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,539 - NuRadioReco.detector - Cable delay not set for channel 7900004 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,542 - NuRadioReco.detector - Cable delay not set for channel 7900005 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,546 - NuRadioReco.detector - Cable delay not set for channel 7900006 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,549 - NuRadioReco.detector - Cable delay not set for channel 7900007 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,553 - NuRadioReco.detector - Cable delay not set for channel 7901008 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,557 - NuRadioReco.detector - Cable delay not set for channel 7901009 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,560 - NuRadioReco.detector - Cable delay not set for channel 7901010 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,563 - NuRadioReco.detector - Cable delay not set for channel 7901011 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,566 - NuRadioReco.detector - Cable delay not set for channel 7901012 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,569 - NuRadioReco.detector - Cable delay not set for channel 7901013 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,573 - NuRadioReco.detector - Cable delay not set for channel 7901014 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,576 - NuRadioReco.detector - Cable delay not set for channel 7901015 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,579 - NuRadioReco.detector - Cable delay not set for channel 7902016 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,582 - NuRadioReco.detector - Cable delay not set for channel 7902017 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,585 - NuRadioReco.detector - Cable delay not set for channel 7902018 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,588 - NuRadioReco.detector - Cable delay not set for channel 7902019 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,591 - NuRadioReco.detector - Cable delay not set for channel 7902020 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,594 - NuRadioReco.detector - Cable delay not set for channel 7902021 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,598 - NuRadioReco.detector - Cable delay not set for channel 7902022 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,601 - NuRadioReco.detector - Cable delay not set for channel 7902023 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,604 - NuRadioReco.detector - Cable delay not set for channel 7903024 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,607 - NuRadioReco.detector - Cable delay not set for channel 7903025 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,610 - NuRadioReco.detector - Cable delay not set for channel 7903026 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,613 - NuRadioReco.detector - Cable delay not set for channel 7903027 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,615 - NuRadioReco.detector - Cable delay not set for channel 7903028 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,619 - NuRadioReco.detector - Cable delay not set for channel 7903029 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,623 - NuRadioReco.detector - Cable delay not set for channel 7903030 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,626 - NuRadioReco.detector - Cable delay not set for channel 7903031 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,629 - NuRadioReco.detector - Cable delay not set for channel 7904032 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,633 - NuRadioReco.detector - Cable delay not set for channel 7904033 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,636 - NuRadioReco.detector - Cable delay not set for channel 7904034 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,639 - NuRadioReco.detector - Cable delay not set for channel 7904035 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,643 - NuRadioReco.detector - Cable delay not set for channel 7904036 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,646 - NuRadioReco.detector - Cable delay not set for channel 7904037 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,649 - NuRadioReco.detector - Cable delay not set for channel 7904038 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,651 - NuRadioReco.detector - Cable delay not set for channel 7904039 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,655 - NuRadioReco.detector - Cable delay not set for channel 7905040 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,658 - NuRadioReco.detector - Cable delay not set for channel 7905041 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,661 - NuRadioReco.detector - Cable delay not set for channel 7905042 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,664 - NuRadioReco.detector - Cable delay not set for channel 7905043 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,667 - NuRadioReco.detector - Cable delay not set for channel 7905044 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,671 - NuRadioReco.detector - Cable delay not set for channel 7905045 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,674 - NuRadioReco.detector - Cable delay not set for channel 7905046 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,677 - NuRadioReco.detector - Cable delay not set for channel 7905047 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,680 - NuRadioReco.detector - Cable delay not set for channel 7906048 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,683 - NuRadioReco.detector - Cable delay not set for channel 7906049 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,686 - NuRadioReco.detector - Cable delay not set for channel 7906050 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,689 - NuRadioReco.detector - Cable delay not set for channel 7906051 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,692 - NuRadioReco.detector - Cable delay not set for channel 7906052 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,695 - NuRadioReco.detector - Cable delay not set for channel 7906053 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,698 - NuRadioReco.detector - Cable delay not set for channel 7906054 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,700 - NuRadioReco.detector - Cable delay not set for channel 7906055 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,705 - NuRadioReco.detector - Cable delay not set for channel 7907056 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,708 - NuRadioReco.detector - Cable delay not set for channel 7907057 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,711 - NuRadioReco.detector - Cable delay not set for channel 7907058 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,715 - NuRadioReco.detector - Cable delay not set for channel 7907059 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,719 - NuRadioReco.detector - Cable delay not set for channel 7907060 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,722 - NuRadioReco.detector - Cable delay not set for channel 7907061 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,725 - NuRadioReco.detector - Cable delay not set for channel 7907062 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,728 - NuRadioReco.detector - Cable delay not set for channel 7907063 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,731 - NuRadioReco.detector - Cable delay not set for channel 7908064 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,734 - NuRadioReco.detector - Cable delay not set for channel 7908065 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,737 - NuRadioReco.detector - Cable delay not set for channel 7908066 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,740 - NuRadioReco.detector - Cable delay not set for channel 7908067 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,743 - NuRadioReco.detector - Cable delay not set for channel 7908068 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,746 - NuRadioReco.detector - Cable delay not set for channel 7908069 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,748 - NuRadioReco.detector - Cable delay not set for channel 7908070 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,752 - NuRadioReco.detector - Cable delay not set for channel 7908071 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,755 - NuRadioReco.detector - Cable delay not set for channel 7909072 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,758 - NuRadioReco.detector - Cable delay not set for channel 7909073 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,761 - NuRadioReco.detector - Cable delay not set for channel 7909074 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,764 - NuRadioReco.detector - Cable delay not set for channel 7909075 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,767 - NuRadioReco.detector - Cable delay not set for channel 7909076 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,770 - NuRadioReco.detector - Cable delay not set for channel 7909077 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,773 - NuRadioReco.detector - Cable delay not set for channel 7909078 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,776 - NuRadioReco.detector - Cable delay not set for channel 7909079 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,779 - NuRadioReco.detector - Cable delay not set for channel 7910080 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,782 - NuRadioReco.detector - Cable delay not set for channel 7910081 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,785 - NuRadioReco.detector - Cable delay not set for channel 7910082 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,788 - NuRadioReco.detector - Cable delay not set for channel 7910083 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,791 - NuRadioReco.detector - Cable delay not set for channel 7910084 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,794 - NuRadioReco.detector - Cable delay not set for channel 7910085 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,797 - NuRadioReco.detector - Cable delay not set for channel 7910086 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,799 - NuRadioReco.detector - Cable delay not set for channel 7910087 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,803 - NuRadioReco.detector - Cable delay not set for channel 7911088 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,806 - NuRadioReco.detector - Cable delay not set for channel 7911089 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,808 - NuRadioReco.detector - Cable delay not set for channel 7911090 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,811 - NuRadioReco.detector - Cable delay not set for channel 7911091 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,814 - NuRadioReco.detector - Cable delay not set for channel 7911092 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,817 - NuRadioReco.detector - Cable delay not set for channel 7911093 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,819 - NuRadioReco.detector - Cable delay not set for channel 7911094 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:20:39,822 - NuRadioReco.detector - Cable delay not set for channel 7911095 in station 7, assuming cable delay is zero
# Calculated Vrms: 3.22e-06 V, applying noise with amplitude 4.55e-06 V

# %%
def extract_signal(nbins, trace):
    dur = nbins*50//2
    am = np.argmax(trace)
    if dur > len(trace)//2:
        print("nbins too large. Cannot extract")
        return None
    elif (dur > am):
        return trace[:2*dur][::50]
    elif (dur > len(trace)-am):
        return trace[-2*dur:][::50]
    else:
        return trace[am-dur:am+dur][::50]

# %%
stn = 1
chn = 76
plt.figure(figsize=(15, 6))
# plt.plot(channel.get_trace(), label="300K")
plt.plot(evt.get_station(stn).get_channel(evt.get_station(stn).get_channel_ids()[chn]).get_trace(), label="0K", alpha=0.8)
# plt.legend()
plt.xlabel("time (ns)")
plt.ylabel("Measured voltage")
plt.savefig("pure_signal.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
nbins = 200
traces = []

for st in evt.get_stations():
    for ch in st.iter_channels():
        trace = ch.get_trace()
        if not np.all(trace == 0):
            traces.append(extract_signal(nbins, trace))

traces = np.array(traces)

# %%
evt0 = reader.read_data_event_with_noise(path_to_coreas_sim_file, selected_station_channel_ids=selected_station_channel_ids, core=core_xy, Tnoise=0 * units.K)
# Out:
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 2 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# warning: negative values in abs_spectrum found: 1 times. Setting to zero.
# WARNING - 2026-08-03 16:24:10,069 - NuRadioReco.detector - Cable delay not set for channel 1000000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,070 - NuRadioReco.detector - Cable delay not set for channel 1000001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,071 - NuRadioReco.detector - Cable delay not set for channel 1000002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,071 - NuRadioReco.detector - Cable delay not set for channel 1000003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,072 - NuRadioReco.detector - Cable delay not set for channel 1000004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,072 - NuRadioReco.detector - Cable delay not set for channel 1000005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,073 - NuRadioReco.detector - Cable delay not set for channel 1000006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,073 - NuRadioReco.detector - Cable delay not set for channel 1000007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,073 - NuRadioReco.detector - Cable delay not set for channel 1001008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,074 - NuRadioReco.detector - Cable delay not set for channel 1001009 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,074 - NuRadioReco.detector - Cable delay not set for channel 1001010 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,074 - NuRadioReco.detector - Cable delay not set for channel 1001011 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,075 - NuRadioReco.detector - Cable delay not set for channel 1001012 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,075 - NuRadioReco.detector - Cable delay not set for channel 1001013 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,076 - NuRadioReco.detector - Cable delay not set for channel 1001014 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,076 - NuRadioReco.detector - Cable delay not set for channel 1001015 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,077 - NuRadioReco.detector - Cable delay not set for channel 1002016 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,077 - NuRadioReco.detector - Cable delay not set for channel 1002017 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,077 - NuRadioReco.detector - Cable delay not set for channel 1002018 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,078 - NuRadioReco.detector - Cable delay not set for channel 1002019 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,078 - NuRadioReco.detector - Cable delay not set for channel 1002020 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,078 - NuRadioReco.detector - Cable delay not set for channel 1002021 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,079 - NuRadioReco.detector - Cable delay not set for channel 1002022 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,079 - NuRadioReco.detector - Cable delay not set for channel 1002023 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,079 - NuRadioReco.detector - Cable delay not set for channel 1003024 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,080 - NuRadioReco.detector - Cable delay not set for channel 1003025 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,080 - NuRadioReco.detector - Cable delay not set for channel 1003026 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,081 - NuRadioReco.detector - Cable delay not set for channel 1003027 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,082 - NuRadioReco.detector - Cable delay not set for channel 1003028 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,082 - NuRadioReco.detector - Cable delay not set for channel 1003029 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,082 - NuRadioReco.detector - Cable delay not set for channel 1003030 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,083 - NuRadioReco.detector - Cable delay not set for channel 1003031 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,083 - NuRadioReco.detector - Cable delay not set for channel 1004032 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,084 - NuRadioReco.detector - Cable delay not set for channel 1004033 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,084 - NuRadioReco.detector - Cable delay not set for channel 1004034 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,085 - NuRadioReco.detector - Cable delay not set for channel 1004035 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,085 - NuRadioReco.detector - Cable delay not set for channel 1004036 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,086 - NuRadioReco.detector - Cable delay not set for channel 1004037 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,087 - NuRadioReco.detector - Cable delay not set for channel 1004038 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,087 - NuRadioReco.detector - Cable delay not set for channel 1004039 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,087 - NuRadioReco.detector - Cable delay not set for channel 1005040 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,088 - NuRadioReco.detector - Cable delay not set for channel 1005041 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,088 - NuRadioReco.detector - Cable delay not set for channel 1005042 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,089 - NuRadioReco.detector - Cable delay not set for channel 1005043 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,090 - NuRadioReco.detector - Cable delay not set for channel 1005044 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,090 - NuRadioReco.detector - Cable delay not set for channel 1005045 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,090 - NuRadioReco.detector - Cable delay not set for channel 1005046 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,091 - NuRadioReco.detector - Cable delay not set for channel 1005047 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,092 - NuRadioReco.detector - Cable delay not set for channel 1006048 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,093 - NuRadioReco.detector - Cable delay not set for channel 1006049 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,093 - NuRadioReco.detector - Cable delay not set for channel 1006050 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,094 - NuRadioReco.detector - Cable delay not set for channel 1006051 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,094 - NuRadioReco.detector - Cable delay not set for channel 1006052 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,095 - NuRadioReco.detector - Cable delay not set for channel 1006053 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,095 - NuRadioReco.detector - Cable delay not set for channel 1006054 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,096 - NuRadioReco.detector - Cable delay not set for channel 1006055 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,096 - NuRadioReco.detector - Cable delay not set for channel 1007056 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,097 - NuRadioReco.detector - Cable delay not set for channel 1007057 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,097 - NuRadioReco.detector - Cable delay not set for channel 1007058 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,098 - NuRadioReco.detector - Cable delay not set for channel 1007059 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,098 - NuRadioReco.detector - Cable delay not set for channel 1007060 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,099 - NuRadioReco.detector - Cable delay not set for channel 1007061 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,099 - NuRadioReco.detector - Cable delay not set for channel 1007062 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,100 - NuRadioReco.detector - Cable delay not set for channel 1007063 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,100 - NuRadioReco.detector - Cable delay not set for channel 1008064 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,101 - NuRadioReco.detector - Cable delay not set for channel 1008065 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,101 - NuRadioReco.detector - Cable delay not set for channel 1008066 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,102 - NuRadioReco.detector - Cable delay not set for channel 1008067 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,102 - NuRadioReco.detector - Cable delay not set for channel 1008068 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,103 - NuRadioReco.detector - Cable delay not set for channel 1008069 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,104 - NuRadioReco.detector - Cable delay not set for channel 1008070 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,104 - NuRadioReco.detector - Cable delay not set for channel 1008071 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,104 - NuRadioReco.detector - Cable delay not set for channel 1009072 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,105 - NuRadioReco.detector - Cable delay not set for channel 1009073 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,106 - NuRadioReco.detector - Cable delay not set for channel 1009074 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,106 - NuRadioReco.detector - Cable delay not set for channel 1009075 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,106 - NuRadioReco.detector - Cable delay not set for channel 1009076 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,107 - NuRadioReco.detector - Cable delay not set for channel 1009077 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,107 - NuRadioReco.detector - Cable delay not set for channel 1009078 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,107 - NuRadioReco.detector - Cable delay not set for channel 1009079 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,108 - NuRadioReco.detector - Cable delay not set for channel 1010080 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,108 - NuRadioReco.detector - Cable delay not set for channel 1010081 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,109 - NuRadioReco.detector - Cable delay not set for channel 1010082 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,109 - NuRadioReco.detector - Cable delay not set for channel 1010083 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,109 - NuRadioReco.detector - Cable delay not set for channel 1010084 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,110 - NuRadioReco.detector - Cable delay not set for channel 1010085 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,110 - NuRadioReco.detector - Cable delay not set for channel 1010086 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,111 - NuRadioReco.detector - Cable delay not set for channel 1010087 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,111 - NuRadioReco.detector - Cable delay not set for channel 1011088 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,111 - NuRadioReco.detector - Cable delay not set for channel 1011089 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,112 - NuRadioReco.detector - Cable delay not set for channel 1011090 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,112 - NuRadioReco.detector - Cable delay not set for channel 1011091 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,113 - NuRadioReco.detector - Cable delay not set for channel 1011092 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,114 - NuRadioReco.detector - Cable delay not set for channel 1011093 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,114 - NuRadioReco.detector - Cable delay not set for channel 1011094 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,115 - NuRadioReco.detector - Cable delay not set for channel 1011095 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,115 - NuRadioReco.detector - Cable delay not set for channel 1900000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,116 - NuRadioReco.detector - Cable delay not set for channel 1900001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,116 - NuRadioReco.detector - Cable delay not set for channel 1900002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,117 - NuRadioReco.detector - Cable delay not set for channel 1900003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,117 - NuRadioReco.detector - Cable delay not set for channel 1900004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,118 - NuRadioReco.detector - Cable delay not set for channel 1900005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,118 - NuRadioReco.detector - Cable delay not set for channel 1900006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,120 - NuRadioReco.detector - Cable delay not set for channel 1900007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,121 - NuRadioReco.detector - Cable delay not set for channel 1901008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,122 - NuRadioReco.detector - Cable delay not set for channel 1901009 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,122 - NuRadioReco.detector - Cable delay not set for channel 1901010 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,123 - NuRadioReco.detector - Cable delay not set for channel 1901011 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,124 - NuRadioReco.detector - Cable delay not set for channel 1901012 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,124 - NuRadioReco.detector - Cable delay not set for channel 1901013 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,124 - NuRadioReco.detector - Cable delay not set for channel 1901014 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,125 - NuRadioReco.detector - Cable delay not set for channel 1901015 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,125 - NuRadioReco.detector - Cable delay not set for channel 1902016 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,126 - NuRadioReco.detector - Cable delay not set for channel 1902017 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,126 - NuRadioReco.detector - Cable delay not set for channel 1902018 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,126 - NuRadioReco.detector - Cable delay not set for channel 1902019 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,127 - NuRadioReco.detector - Cable delay not set for channel 1902020 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,127 - NuRadioReco.detector - Cable delay not set for channel 1902021 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,128 - NuRadioReco.detector - Cable delay not set for channel 1902022 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,128 - NuRadioReco.detector - Cable delay not set for channel 1902023 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,129 - NuRadioReco.detector - Cable delay not set for channel 1903024 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,129 - NuRadioReco.detector - Cable delay not set for channel 1903025 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,129 - NuRadioReco.detector - Cable delay not set for channel 1903026 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,131 - NuRadioReco.detector - Cable delay not set for channel 1903027 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,131 - NuRadioReco.detector - Cable delay not set for channel 1903028 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,132 - NuRadioReco.detector - Cable delay not set for channel 1903029 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,132 - NuRadioReco.detector - Cable delay not set for channel 1903030 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,132 - NuRadioReco.detector - Cable delay not set for channel 1903031 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,133 - NuRadioReco.detector - Cable delay not set for channel 1904032 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,133 - NuRadioReco.detector - Cable delay not set for channel 1904033 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,134 - NuRadioReco.detector - Cable delay not set for channel 1904034 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,134 - NuRadioReco.detector - Cable delay not set for channel 1904035 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,135 - NuRadioReco.detector - Cable delay not set for channel 1904036 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,136 - NuRadioReco.detector - Cable delay not set for channel 1904037 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,136 - NuRadioReco.detector - Cable delay not set for channel 1904038 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,137 - NuRadioReco.detector - Cable delay not set for channel 1904039 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,137 - NuRadioReco.detector - Cable delay not set for channel 1905040 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,138 - NuRadioReco.detector - Cable delay not set for channel 1905041 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,138 - NuRadioReco.detector - Cable delay not set for channel 1905042 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,139 - NuRadioReco.detector - Cable delay not set for channel 1905043 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,139 - NuRadioReco.detector - Cable delay not set for channel 1905044 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,140 - NuRadioReco.detector - Cable delay not set for channel 1905045 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,140 - NuRadioReco.detector - Cable delay not set for channel 1905046 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,140 - NuRadioReco.detector - Cable delay not set for channel 1905047 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,141 - NuRadioReco.detector - Cable delay not set for channel 1906048 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,141 - NuRadioReco.detector - Cable delay not set for channel 1906049 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,141 - NuRadioReco.detector - Cable delay not set for channel 1906050 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,142 - NuRadioReco.detector - Cable delay not set for channel 1906051 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,142 - NuRadioReco.detector - Cable delay not set for channel 1906052 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,143 - NuRadioReco.detector - Cable delay not set for channel 1906053 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,143 - NuRadioReco.detector - Cable delay not set for channel 1906054 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,144 - NuRadioReco.detector - Cable delay not set for channel 1906055 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,144 - NuRadioReco.detector - Cable delay not set for channel 1907056 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,145 - NuRadioReco.detector - Cable delay not set for channel 1907057 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,145 - NuRadioReco.detector - Cable delay not set for channel 1907058 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,145 - NuRadioReco.detector - Cable delay not set for channel 1907059 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,146 - NuRadioReco.detector - Cable delay not set for channel 1907060 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,146 - NuRadioReco.detector - Cable delay not set for channel 1907061 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,147 - NuRadioReco.detector - Cable delay not set for channel 1907062 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,147 - NuRadioReco.detector - Cable delay not set for channel 1907063 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,148 - NuRadioReco.detector - Cable delay not set for channel 1908064 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,148 - NuRadioReco.detector - Cable delay not set for channel 1908065 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,149 - NuRadioReco.detector - Cable delay not set for channel 1908066 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,149 - NuRadioReco.detector - Cable delay not set for channel 1908067 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,149 - NuRadioReco.detector - Cable delay not set for channel 1908068 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,150 - NuRadioReco.detector - Cable delay not set for channel 1908069 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,150 - NuRadioReco.detector - Cable delay not set for channel 1908070 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,151 - NuRadioReco.detector - Cable delay not set for channel 1908071 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,151 - NuRadioReco.detector - Cable delay not set for channel 1909072 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,152 - NuRadioReco.detector - Cable delay not set for channel 1909073 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,152 - NuRadioReco.detector - Cable delay not set for channel 1909074 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,153 - NuRadioReco.detector - Cable delay not set for channel 1909075 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,154 - NuRadioReco.detector - Cable delay not set for channel 1909076 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,154 - NuRadioReco.detector - Cable delay not set for channel 1909077 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,155 - NuRadioReco.detector - Cable delay not set for channel 1909078 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,155 - NuRadioReco.detector - Cable delay not set for channel 1909079 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,155 - NuRadioReco.detector - Cable delay not set for channel 1910080 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,156 - NuRadioReco.detector - Cable delay not set for channel 1910081 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,156 - NuRadioReco.detector - Cable delay not set for channel 1910082 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,157 - NuRadioReco.detector - Cable delay not set for channel 1910083 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,158 - NuRadioReco.detector - Cable delay not set for channel 1910084 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,158 - NuRadioReco.detector - Cable delay not set for channel 1910085 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,158 - NuRadioReco.detector - Cable delay not set for channel 1910086 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,159 - NuRadioReco.detector - Cable delay not set for channel 1910087 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,159 - NuRadioReco.detector - Cable delay not set for channel 1911088 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,160 - NuRadioReco.detector - Cable delay not set for channel 1911089 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,160 - NuRadioReco.detector - Cable delay not set for channel 1911090 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,161 - NuRadioReco.detector - Cable delay not set for channel 1911091 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,161 - NuRadioReco.detector - Cable delay not set for channel 1911092 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,161 - NuRadioReco.detector - Cable delay not set for channel 1911093 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,162 - NuRadioReco.detector - Cable delay not set for channel 1911094 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,162 - NuRadioReco.detector - Cable delay not set for channel 1911095 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,163 - NuRadioReco.detector - Cable delay not set for channel 1000000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,166 - NuRadioReco.efieldToVoltageConverter - Frequencies have changed (array length). Clearing antenna response cache. If you similate neutrinos/in-ice radio emission, this is not surprising. Please disable caching By passing `caching==False` to the begin method. If you simulate air showers and this happens often, something might be wrong...
# WARNING - 2026-08-03 16:24:10,169 - NuRadioReco.detector - Cable delay not set for channel 1000001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,175 - NuRadioReco.detector - Cable delay not set for channel 1000002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,179 - NuRadioReco.detector - Cable delay not set for channel 1000003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,182 - NuRadioReco.detector - Cable delay not set for channel 1000004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,186 - NuRadioReco.detector - Cable delay not set for channel 1000005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,191 - NuRadioReco.detector - Cable delay not set for channel 1000006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,196 - NuRadioReco.detector - Cable delay not set for channel 1000007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,201 - NuRadioReco.detector - Cable delay not set for channel 1001008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,208 - NuRadioReco.detector - Cable delay not set for channel 1001009 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,213 - NuRadioReco.detector - Cable delay not set for channel 1001010 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,221 - NuRadioReco.detector - Cable delay not set for channel 1001011 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,226 - NuRadioReco.detector - Cable delay not set for channel 1001012 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,230 - NuRadioReco.detector - Cable delay not set for channel 1001013 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,234 - NuRadioReco.detector - Cable delay not set for channel 1001014 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,238 - NuRadioReco.detector - Cable delay not set for channel 1001015 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,243 - NuRadioReco.detector - Cable delay not set for channel 1002016 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,247 - NuRadioReco.detector - Cable delay not set for channel 1002017 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,251 - NuRadioReco.detector - Cable delay not set for channel 1002018 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,256 - NuRadioReco.detector - Cable delay not set for channel 1002019 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,260 - NuRadioReco.detector - Cable delay not set for channel 1002020 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,264 - NuRadioReco.detector - Cable delay not set for channel 1002021 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,268 - NuRadioReco.detector - Cable delay not set for channel 1002022 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,273 - NuRadioReco.detector - Cable delay not set for channel 1002023 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,277 - NuRadioReco.detector - Cable delay not set for channel 1003024 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,281 - NuRadioReco.detector - Cable delay not set for channel 1003025 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,285 - NuRadioReco.detector - Cable delay not set for channel 1003026 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,289 - NuRadioReco.detector - Cable delay not set for channel 1003027 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,294 - NuRadioReco.detector - Cable delay not set for channel 1003028 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,298 - NuRadioReco.detector - Cable delay not set for channel 1003029 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,302 - NuRadioReco.detector - Cable delay not set for channel 1003030 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,306 - NuRadioReco.detector - Cable delay not set for channel 1003031 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,311 - NuRadioReco.detector - Cable delay not set for channel 1004032 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,315 - NuRadioReco.detector - Cable delay not set for channel 1004033 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,319 - NuRadioReco.detector - Cable delay not set for channel 1004034 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,323 - NuRadioReco.detector - Cable delay not set for channel 1004035 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,327 - NuRadioReco.detector - Cable delay not set for channel 1004036 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,331 - NuRadioReco.detector - Cable delay not set for channel 1004037 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,334 - NuRadioReco.detector - Cable delay not set for channel 1004038 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,338 - NuRadioReco.detector - Cable delay not set for channel 1004039 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,343 - NuRadioReco.detector - Cable delay not set for channel 1005040 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,347 - NuRadioReco.detector - Cable delay not set for channel 1005041 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,351 - NuRadioReco.detector - Cable delay not set for channel 1005042 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,356 - NuRadioReco.detector - Cable delay not set for channel 1005043 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,360 - NuRadioReco.detector - Cable delay not set for channel 1005044 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,364 - NuRadioReco.detector - Cable delay not set for channel 1005045 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,368 - NuRadioReco.detector - Cable delay not set for channel 1005046 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,372 - NuRadioReco.detector - Cable delay not set for channel 1005047 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,377 - NuRadioReco.detector - Cable delay not set for channel 1006048 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,380 - NuRadioReco.detector - Cable delay not set for channel 1006049 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,383 - NuRadioReco.detector - Cable delay not set for channel 1006050 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,386 - NuRadioReco.detector - Cable delay not set for channel 1006051 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,389 - NuRadioReco.detector - Cable delay not set for channel 1006052 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,393 - NuRadioReco.detector - Cable delay not set for channel 1006053 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,396 - NuRadioReco.detector - Cable delay not set for channel 1006054 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,399 - NuRadioReco.detector - Cable delay not set for channel 1006055 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,403 - NuRadioReco.detector - Cable delay not set for channel 1007056 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,406 - NuRadioReco.detector - Cable delay not set for channel 1007057 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,410 - NuRadioReco.detector - Cable delay not set for channel 1007058 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,414 - NuRadioReco.detector - Cable delay not set for channel 1007059 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,417 - NuRadioReco.detector - Cable delay not set for channel 1007060 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,420 - NuRadioReco.detector - Cable delay not set for channel 1007061 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,424 - NuRadioReco.detector - Cable delay not set for channel 1007062 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,427 - NuRadioReco.detector - Cable delay not set for channel 1007063 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,431 - NuRadioReco.detector - Cable delay not set for channel 1008064 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,434 - NuRadioReco.detector - Cable delay not set for channel 1008065 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,438 - NuRadioReco.detector - Cable delay not set for channel 1008066 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,443 - NuRadioReco.detector - Cable delay not set for channel 1008067 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,447 - NuRadioReco.detector - Cable delay not set for channel 1008068 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,449 - NuRadioReco.detector - Cable delay not set for channel 1008069 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,453 - NuRadioReco.detector - Cable delay not set for channel 1008070 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,457 - NuRadioReco.detector - Cable delay not set for channel 1008071 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,460 - NuRadioReco.detector - Cable delay not set for channel 1009072 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,463 - NuRadioReco.detector - Cable delay not set for channel 1009073 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,466 - NuRadioReco.detector - Cable delay not set for channel 1009074 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,469 - NuRadioReco.detector - Cable delay not set for channel 1009075 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,473 - NuRadioReco.detector - Cable delay not set for channel 1009076 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,476 - NuRadioReco.detector - Cable delay not set for channel 1009077 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,480 - NuRadioReco.detector - Cable delay not set for channel 1009078 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,483 - NuRadioReco.detector - Cable delay not set for channel 1009079 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,486 - NuRadioReco.detector - Cable delay not set for channel 1010080 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,489 - NuRadioReco.detector - Cable delay not set for channel 1010081 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,493 - NuRadioReco.detector - Cable delay not set for channel 1010082 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,496 - NuRadioReco.detector - Cable delay not set for channel 1010083 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,499 - NuRadioReco.detector - Cable delay not set for channel 1010084 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,503 - NuRadioReco.detector - Cable delay not set for channel 1010085 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,507 - NuRadioReco.detector - Cable delay not set for channel 1010086 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,510 - NuRadioReco.detector - Cable delay not set for channel 1010087 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,514 - NuRadioReco.detector - Cable delay not set for channel 1011088 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,518 - NuRadioReco.detector - Cable delay not set for channel 1011089 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,521 - NuRadioReco.detector - Cable delay not set for channel 1011090 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,525 - NuRadioReco.detector - Cable delay not set for channel 1011091 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,528 - NuRadioReco.detector - Cable delay not set for channel 1011092 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,531 - NuRadioReco.detector - Cable delay not set for channel 1011093 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,534 - NuRadioReco.detector - Cable delay not set for channel 1011094 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,538 - NuRadioReco.detector - Cable delay not set for channel 1011095 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,542 - NuRadioReco.detector - Cable delay not set for channel 1900000 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,545 - NuRadioReco.detector - Cable delay not set for channel 1900001 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,549 - NuRadioReco.detector - Cable delay not set for channel 1900002 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,554 - NuRadioReco.detector - Cable delay not set for channel 1900003 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,558 - NuRadioReco.detector - Cable delay not set for channel 1900004 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,562 - NuRadioReco.detector - Cable delay not set for channel 1900005 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,565 - NuRadioReco.detector - Cable delay not set for channel 1900006 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,568 - NuRadioReco.detector - Cable delay not set for channel 1900007 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,572 - NuRadioReco.detector - Cable delay not set for channel 1901008 in station 1, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:10,576 - NuRadioReco.detector - Cable delay not set for channel 1901009 in station 1, assuming cable delay is zero
# ...
# WARNING - 2026-08-03 16:24:30,232 - NuRadioReco.detector - Cable delay not set for channel 7010080 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,235 - NuRadioReco.detector - Cable delay not set for channel 7010081 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,238 - NuRadioReco.detector - Cable delay not set for channel 7010082 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,242 - NuRadioReco.detector - Cable delay not set for channel 7010083 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,245 - NuRadioReco.detector - Cable delay not set for channel 7010084 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,248 - NuRadioReco.detector - Cable delay not set for channel 7010085 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,250 - NuRadioReco.detector - Cable delay not set for channel 7010086 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,253 - NuRadioReco.detector - Cable delay not set for channel 7010087 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,257 - NuRadioReco.detector - Cable delay not set for channel 7011088 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,260 - NuRadioReco.detector - Cable delay not set for channel 7011089 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,263 - NuRadioReco.detector - Cable delay not set for channel 7011090 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,266 - NuRadioReco.detector - Cable delay not set for channel 7011091 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,269 - NuRadioReco.detector - Cable delay not set for channel 7011092 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,272 - NuRadioReco.detector - Cable delay not set for channel 7011093 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,275 - NuRadioReco.detector - Cable delay not set for channel 7011094 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,279 - NuRadioReco.detector - Cable delay not set for channel 7011095 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,282 - NuRadioReco.detector - Cable delay not set for channel 7900000 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,285 - NuRadioReco.detector - Cable delay not set for channel 7900001 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,288 - NuRadioReco.detector - Cable delay not set for channel 7900002 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,291 - NuRadioReco.detector - Cable delay not set for channel 7900003 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,294 - NuRadioReco.detector - Cable delay not set for channel 7900004 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,297 - NuRadioReco.detector - Cable delay not set for channel 7900005 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,300 - NuRadioReco.detector - Cable delay not set for channel 7900006 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,303 - NuRadioReco.detector - Cable delay not set for channel 7900007 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,306 - NuRadioReco.detector - Cable delay not set for channel 7901008 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,310 - NuRadioReco.detector - Cable delay not set for channel 7901009 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,313 - NuRadioReco.detector - Cable delay not set for channel 7901010 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,316 - NuRadioReco.detector - Cable delay not set for channel 7901011 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,319 - NuRadioReco.detector - Cable delay not set for channel 7901012 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,322 - NuRadioReco.detector - Cable delay not set for channel 7901013 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,326 - NuRadioReco.detector - Cable delay not set for channel 7901014 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,329 - NuRadioReco.detector - Cable delay not set for channel 7901015 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,332 - NuRadioReco.detector - Cable delay not set for channel 7902016 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,334 - NuRadioReco.detector - Cable delay not set for channel 7902017 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,337 - NuRadioReco.detector - Cable delay not set for channel 7902018 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,341 - NuRadioReco.detector - Cable delay not set for channel 7902019 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,343 - NuRadioReco.detector - Cable delay not set for channel 7902020 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,346 - NuRadioReco.detector - Cable delay not set for channel 7902021 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,350 - NuRadioReco.detector - Cable delay not set for channel 7902022 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,353 - NuRadioReco.detector - Cable delay not set for channel 7902023 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,356 - NuRadioReco.detector - Cable delay not set for channel 7903024 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,359 - NuRadioReco.detector - Cable delay not set for channel 7903025 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,363 - NuRadioReco.detector - Cable delay not set for channel 7903026 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,366 - NuRadioReco.detector - Cable delay not set for channel 7903027 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,369 - NuRadioReco.detector - Cable delay not set for channel 7903028 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,372 - NuRadioReco.detector - Cable delay not set for channel 7903029 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,376 - NuRadioReco.detector - Cable delay not set for channel 7903030 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,380 - NuRadioReco.detector - Cable delay not set for channel 7903031 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,384 - NuRadioReco.detector - Cable delay not set for channel 7904032 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,388 - NuRadioReco.detector - Cable delay not set for channel 7904033 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,392 - NuRadioReco.detector - Cable delay not set for channel 7904034 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,397 - NuRadioReco.detector - Cable delay not set for channel 7904035 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,402 - NuRadioReco.detector - Cable delay not set for channel 7904036 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,406 - NuRadioReco.detector - Cable delay not set for channel 7904037 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,410 - NuRadioReco.detector - Cable delay not set for channel 7904038 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,414 - NuRadioReco.detector - Cable delay not set for channel 7904039 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,418 - NuRadioReco.detector - Cable delay not set for channel 7905040 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,421 - NuRadioReco.detector - Cable delay not set for channel 7905041 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,424 - NuRadioReco.detector - Cable delay not set for channel 7905042 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,428 - NuRadioReco.detector - Cable delay not set for channel 7905043 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,431 - NuRadioReco.detector - Cable delay not set for channel 7905044 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,434 - NuRadioReco.detector - Cable delay not set for channel 7905045 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,438 - NuRadioReco.detector - Cable delay not set for channel 7905046 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,441 - NuRadioReco.detector - Cable delay not set for channel 7905047 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,445 - NuRadioReco.detector - Cable delay not set for channel 7906048 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,448 - NuRadioReco.detector - Cable delay not set for channel 7906049 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,452 - NuRadioReco.detector - Cable delay not set for channel 7906050 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,456 - NuRadioReco.detector - Cable delay not set for channel 7906051 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,460 - NuRadioReco.detector - Cable delay not set for channel 7906052 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,463 - NuRadioReco.detector - Cable delay not set for channel 7906053 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,466 - NuRadioReco.detector - Cable delay not set for channel 7906054 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,469 - NuRadioReco.detector - Cable delay not set for channel 7906055 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,472 - NuRadioReco.detector - Cable delay not set for channel 7907056 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,476 - NuRadioReco.detector - Cable delay not set for channel 7907057 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,479 - NuRadioReco.detector - Cable delay not set for channel 7907058 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,482 - NuRadioReco.detector - Cable delay not set for channel 7907059 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,485 - NuRadioReco.detector - Cable delay not set for channel 7907060 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,488 - NuRadioReco.detector - Cable delay not set for channel 7907061 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,491 - NuRadioReco.detector - Cable delay not set for channel 7907062 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,494 - NuRadioReco.detector - Cable delay not set for channel 7907063 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,498 - NuRadioReco.detector - Cable delay not set for channel 7908064 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,501 - NuRadioReco.detector - Cable delay not set for channel 7908065 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,505 - NuRadioReco.detector - Cable delay not set for channel 7908066 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,508 - NuRadioReco.detector - Cable delay not set for channel 7908067 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,512 - NuRadioReco.detector - Cable delay not set for channel 7908068 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,515 - NuRadioReco.detector - Cable delay not set for channel 7908069 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,518 - NuRadioReco.detector - Cable delay not set for channel 7908070 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,522 - NuRadioReco.detector - Cable delay not set for channel 7908071 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,525 - NuRadioReco.detector - Cable delay not set for channel 7909072 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,529 - NuRadioReco.detector - Cable delay not set for channel 7909073 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,532 - NuRadioReco.detector - Cable delay not set for channel 7909074 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,534 - NuRadioReco.detector - Cable delay not set for channel 7909075 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,537 - NuRadioReco.detector - Cable delay not set for channel 7909076 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,541 - NuRadioReco.detector - Cable delay not set for channel 7909077 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,544 - NuRadioReco.detector - Cable delay not set for channel 7909078 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,547 - NuRadioReco.detector - Cable delay not set for channel 7909079 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,551 - NuRadioReco.detector - Cable delay not set for channel 7910080 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,554 - NuRadioReco.detector - Cable delay not set for channel 7910081 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,558 - NuRadioReco.detector - Cable delay not set for channel 7910082 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,561 - NuRadioReco.detector - Cable delay not set for channel 7910083 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,565 - NuRadioReco.detector - Cable delay not set for channel 7910084 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,568 - NuRadioReco.detector - Cable delay not set for channel 7910085 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,571 - NuRadioReco.detector - Cable delay not set for channel 7910086 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,574 - NuRadioReco.detector - Cable delay not set for channel 7910087 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,577 - NuRadioReco.detector - Cable delay not set for channel 7911088 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,580 - NuRadioReco.detector - Cable delay not set for channel 7911089 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,583 - NuRadioReco.detector - Cable delay not set for channel 7911090 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,586 - NuRadioReco.detector - Cable delay not set for channel 7911091 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,590 - NuRadioReco.detector - Cable delay not set for channel 7911092 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,593 - NuRadioReco.detector - Cable delay not set for channel 7911093 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,595 - NuRadioReco.detector - Cable delay not set for channel 7911094 in station 7, assuming cable delay is zero
# WARNING - 2026-08-03 16:24:30,598 - NuRadioReco.detector - Cable delay not set for channel 7911095 in station 7, assuming cable delay is zero
# Calculated Vrms: 0.00e+00 V, applying noise with amplitude 0.00e+00 V

# %%
nbins = 200
traces0 = []

for st in evt0.get_stations():
    for ch in st.iter_channels():
        trace = ch.get_trace()
        if not np.all(trace == 0):
            traces0.append(extract_signal(nbins, trace))

traces0 = np.array(traces0)

# %%
np.save(f"../test_cov/data/traces_allchan_{nbins}.npy", traces)
np.save(f"../test_cov/data/true_allchan_{nbins}.npy", traces0)
